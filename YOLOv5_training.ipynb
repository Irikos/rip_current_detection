# %%
print("Hello, world!")
print("This notebook is dedicated to customly training / tuning YOLOv5 for rip current detection.")
print("Starting project...")

# so far I've trained
# - yolov5s pretrained - done
# - yolov5s custom - done

# - yolov5m pretrained - in training
# - yolo5m custom - todo
# Out:
# Hello, world!
# This notebook is dedicated to customly training / tuning YOLOv5 for rip current detection.
# Starting project...

# %%
# YOLO train v5s pretrained initial weights
# !python ./yolov5/train.py --img 640 --cfg ./yolov5/models/yolov5s.yaml --hyp ./yolov5/data/hyps/hyp.scratch.yaml --batch 80 --epochs 300 --data ./yolov5/rip_detection.yaml --weights yolov5s.pt --workers 24 --name yolo_v5s_pretrained_v0.2
# Out:
# train: weights=yolov5s.pt, cfg=./yolov5/models/yolov5s.yaml, data=./yolov5/rip_detection.yaml, hyp=./yolov5/data/hyps/hyp.scratch.yaml, epochs=300, batch_size=80, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=24, project=runs/train, entity=None, name=yolo_v5s_pretrained_v0.2, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-351-ge96c74b torch 1.8.0a0+52ea372 CUDA:0 (Quadro P5000, 16278.5625MB)
#
# ...

# %%
# YOLO train v5s random initial weights
# !python ./yolov5/train.py --img 640 --cfg ./yolov5/models/yolov5s.yaml --hyp ./yolov5/data/hyps/hyp.scratch.yaml --batch 80 --epochs 300 --data ./yolov5/rip_detection.yaml --weights '' --workers 24 --name yolo_v5s_custom_v0.2
# Out:
# detect: weights=['./runs/train/yolo_v5s_pretrained/weights/best.pt'], source=./datasets/custom_data/belona_test03.mp4, imgsz=640, conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolo_v5s_pretrained_belona_test03, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# requirements: /notebooks/RIPCurrentDetection/requirements.txt not found, check failed.
# YOLOv5 🚀 v5.0-351-ge96c74b torch 1.8.0a0+52ea372 CUDA:0 (Quadro P5000, 16278.5625MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/5815) /notebooks/RIPCurrentDetection/datasets/custom_data/belona_test03.mp4: 384x640 Done. (0.023s)
# video 1/1 (2/5815) /notebooks/RIPCurrentDetection/datasets/custom_data/belona_test03.mp4: 384x640 Done. (0.021s)
# ...

# %%
# YOLO train v5m pretrained initial weights
# !python ./yolov5/train.py --img 640 --cfg ./yolov5/models/yolov5m.yaml --hyp ./yolov5/data/hyps/hyp.scratch.yaml --batch 32 --epochs 300 --data ./yolov5/rip_detection.yaml --weights yolov5m.pt --workers 24 --name yolo_v5m_pretrained_v0.1
# Out:
# train: weights=./yolov5m.pt, cfg=./yolov5/models/yolov5m.yaml, data=./yolov5/rip_detection.yaml, hyp=./yolov5/data/hyps/hyp.scratch.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=24, project=runs/train, entity=None, name=yolo_v5m_pretrained, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-351-ge96c74b torch 1.8.0a0+52ea372 CUDA:0 (Quadro P5000, 16278.5625MB)
#
# ...

# %%
# YOLO train v5m random initial weights
# !python ./yolov5/train.py --img 640 --cfg ./yolov5/models/yolov5m.yaml --hyp ./yolov5/data/hyps/hyp.scratch.yaml --batch 32 --epochs 300 --data ./yolov5/rip_detection.yaml --weights '' --workers 24 --name yolo_v5m_custom_v0.1
