# %%
print("Hello, world!")
print("Notebook for creating & testing helper functions.")
print("Import the Python file, not the notebook, for actual use.")
# Out:
# Hello, world!
# Notebook for creating & testing helper functions.
# Import the Python file, not the notebook, for actual use.

# %%
# Imports
print("Importing libraries...")
# YOLO STUFF
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt


# my stuff
import cv2 as cv
import os
import io
import glob
import PIL
from IPython.display import clear_output, Image, display

print("Done importing libraries.")
# Out:
# Importing libraries...
# Done importing libraries.

# %%
## global folders
### global stuff
# DATA_FOLDER:
# contains data_labels.txt, with_rips folder images and without_rips folder images
DATA_FOLDER = "/home/ext/dumitriu/datasets/rip_current_akila" 
RIPS_FOLDER = "/home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips" 
YOLO_ANNOTATIONS_FOLDER = "/home/ext/dumitriu/datasets/rip_current_akila/yolo_annotations/"

TRAIN_FOLDER = "/home/ext/dumitriu/datasets/rip_current_akila/training_data" 
TEST_FOLDER = "/home/ext/dumitriu/datasets/rip_current_akila/training_data" 
VAL_FOLDER = "/home/ext/dumitriu/datasets/rip_current_akila/training_data" 

# ANNOTATIONS_TRAIN_FOLDER = './datasets/labels/train'
# ANNOTATIONS_TEST_FOLDER = './datasets/labels/test'
# ANNOTATIONS_VAL_FOLDER = './datasets/labels/val'

yolo_annotations_files = glob.glob(os.path.join(YOLO_ANNOTATIONS_FOLDER, "*.txt")) 
images_rip = glob.glob(os.path.join(DATA_FOLDER, "with_rips/*.png")) 
images_norip = glob.glob(os.path.join(DATA_FOLDER, "without_rips/*.png")) 

### CONTROL VARIABLES
CREATE_YOLO_ANNOTATIONS = False 
COPY_FILES = False

# %%
# Reading the RIP annotation from the paper's dataset
# After we read it, we convert it to yolo's format
def read_RIP_annotations(filename = os.path.join(DATA_FOLDER, "data_labels.txt"), verbose=False):
    print("Reading file", filename)
    file = open(filename, "r")
    
    labels = file.readline()
    print("File labels:", labels)
    new_line = file.readline()
    
    images_dict = []
    while (new_line):
        # Get details from annotation line
        items = new_line.split(',')
        image_details = {}
        image_details['filename'] = items[0]
        
        image_details['xmin'] = items[1]
        image_details['ymin'] = items[2]
        image_details['xmax'] = items[3]
        image_details['ymax'] = items[4]
 
 #       image_details['class'] = items[5][:-1]
        image_details['class'] = '0'
        
        # Read image for width and height
        image_path = glob.glob(os.path.join(RIPS_FOLDER, image_details['filename'])) 
        if(verbose==True):
            print(os.path.join(RIPS_FOLDER, image_details['filename']))
        image = PIL.Image.open(image_path[0])
        width, height = image.size
        image_details["width"] = width
        image_details["height"] = height
        image_details["image"] = image
        
        new_line = file.readline()
        
        images_dict.append(image_details)
    
    file.close()
    print("Finished parsing data from file.")
    return images_dict
        
# yolo bbox format: b_class, b_center_x, b_center_y, b_width, b_height
# This function takes the dictionary generated at the previous function, reads it, creates a line of yolo format and writes a file for each image
def convert_to_yolo(images_dict):
    for image in images_dict:
        filename = image['filename'][:-4] + '.txt'
        file_full_path = os.path.join(DATA_FOLDER, "yolo_annotations", filename)
        file = open(file_full_path, "w")
        
        # bbox coordonates for yolo format
        b_center_x = (int(image['xmin']) + int(image['xmax'])) / 2
        b_center_y = (int(image['ymin']) + int(image['ymax'])) / 2
        b_width = (int(image['xmax']) - int(image['xmin']))
        b_height = (int(image['ymax']) - int(image['ymin']))
        
        # Normalise the coordinates by the dimensions of the image
        b_center_x /= int(image['width'])
        b_center_y /= int(image['height'])
        b_width /= int(image['width'])
        b_height /= int(image['height'])
        
        b_center_x = round(b_center_x, 3)
        b_center_y = round(b_center_y, 3)
        b_width = round(b_width, 3)
        b_height = round(b_height, 3)
        
        yolo_line = " "
        yolo_items = [image["class"], str(b_center_x), str(b_center_y), str(b_width), str(b_height)]
        yolo_line = yolo_line.join(yolo_items)
        
        file.write(yolo_line)
        file.close()
    
# Reads the annotations from the yolo files into a dictionary of dictionaries. A bit redundant and will have to change, but I want to be able to read the data directly.
# Format: yolo_dict[<filename>] = {'class', 'b_center_x', 'b_center_y', 'b_width', 'b_height'}
def read_yolo_annotations():
    yolo_dict = {}
    for yolo_file in yolo_annotations_files:
        filename = yolo_file.split('/')[-1].split('.')[-2]
        file = open(yolo_file, 'r')
        line = file.readline()
        split_line = line.split(' ')
        yolo_dict[filename] = {}
        if (yolo_dict[filename]):
            print ("Key exists ", filename)
        else:
            yolo_dict[filename]['class'] = split_line[0]
            yolo_dict[filename]['b_center_x'] = split_line[1]
            yolo_dict[filename]['b_center_y'] = split_line[2]
            yolo_dict[filename]['b_width'] = split_line[3]
            yolo_dict[filename]['b_height'] = split_line[4]
        file.close()
    return yolo_dict

def draw_yolo_annotations(image, yolo_annotations):
    full_name = image + '.png'
    img_original = cv.imread(os.path.join(RIPS_FOLDER, full_name))
    img_details = PIL.Image.open(os.path.join(RIPS_FOLDER, full_name))
    img = img_original.copy()
    width, height = img_details.size
    b_center_x = int(float(yolo_annotations[image]['b_center_x']) * width)
    b_center_y = int(float(yolo_annotations[image]['b_center_y']) * height)
    b_width = int(float(yolo_annotations[image]['b_width']) * width)
    b_height = int(float(yolo_annotations[image]['b_height']) * height)
    
    b_min_x = b_center_x - int(b_width / 2)
    b_min_y = b_center_y - int(b_height / 2)
    
    b_max_x = b_center_x + int(b_width / 2)
    b_max_y = b_center_y + int(b_height / 2)
    
#     img_circle = cv.circle(img, (b_center_x, b_center_y), 5, (0, 0, 0), 5)
    img_rect = cv.rectangle(img, (b_max_x, b_max_y), (b_min_x, b_min_y), (0, 0, 255), 2)
#     show_image(img)
    return img_rect

# functions for reading and displaying an image, taken from Bogdan Alexe's course and project

def show_image(a, fmt='jpeg'):
    if(len(a.shape)) == 3:
        a = cv.cvtColor(a, cv.COLOR_BGR2RGB)
    a = np.uint8(np.clip(a, 0, 255))
    f = io.BytesIO()
    PIL.Image.fromarray(a).save(f, fmt)
    display(Image(data=f.getvalue()))
    
def read_image(index, source, resize):
    image = cv.imread(source[index])
    return cv.resize(image, (0, 0), fx=resize, fy=resize)

# quickfix because apparently there are more RIP images than annotations
# final fix should involve cleaning the dataset completely

def build_files_from_annotations(annotations, path):
    images = []
    for item in annotations:
        name = item.split('/')[-1].split('.')[-2]
        complete_path = path + name + '.png'
        images.append(complete_path)
    return images

def copy_files_to_folder(list_of_files, destination_folder):
    for file in list_of_files:
        try:
            shutil.copy(file, destination_folder)
        except:
            print(file)
            assert False
            
# needs improvement to actually make sense
def change_yolo_annotation_class(annotations, new_class):
    for yolo_file in coco_rip_files:
        print(yolo_file)
        file = open(yolo_file, 'r')
        line = file.readline()
        split_line = line.split(' ')
        file.close()
        file = open(yolo_file, 'w')
        split_line[0] = str(1)
        split_line[1] = str(split_line[1])
        split_line[2] = str(split_line[2])
        split_line[3] = str(split_line[3])
        split_line[4] = str(split_line[4])
        newline = (' ').join(split_line)    
        file.write(newline)
        file.close()

def get_image_from_annotation_path(annotation_path):
    train_or_val = annotation_path.split('/')[-2]
    image_name = annotation_path.split('/')[-1].split('.')[-2]
    return os.path.join('./datasets/coco/images/', train_or_val, image_name + '.jpg')

# %%
if (CREATE_YOLO_ANNOTATIONS == True):
    print("Reading labels...")
    images_dict = read_RIP_annotations()
    print("Converting annotations to yolo format and writing files.")
    convert_to_yolo(images_dict)
    print("Finished writing yolo annotations to files.")
else:
    print("Yolo annotations already created (assumption). Skipping the read and write part.")
# Out:
# Reading labels...
# Reading file /home/ext/dumitriu/datasets/rip_current_akila/data_labels.txt
# File labels: rip-1568.png,238,69,608,582,rip
#
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-581.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1366.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1600.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-613.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1398.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1632.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-645.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1435.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1664.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-677.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1467.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1696.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-709.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1728.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-746.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1760.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-780.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-25.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-813.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-57.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-845.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-93.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-877.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-125.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-909.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-157.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-941.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-189.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-973.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-221.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1005.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-253.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1037.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-285.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1069.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-317.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1101.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-349.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1137.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-383.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1174.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-415.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1206.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-453.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1238.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-485.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1270.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1504.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-517.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1302.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1536.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-549.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1334.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1337.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1571.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-584.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1369.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1603.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-616.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1401.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1635.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-648.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1438.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1667.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-680.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1470.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-712.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1731.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-749.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1763.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-783.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-28.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-816.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-60.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-848.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-96.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-128.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-912.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-160.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-944.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-192.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-224.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1008.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-256.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1040.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-288.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1072.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-320.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1104.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-352.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1145.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-386.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1177.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-418.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1209.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-456.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1241.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-488.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1273.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1507.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-520.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1305.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1539.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-552.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1340.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-587.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1372.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-619.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1404.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1638.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-651.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1441.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1670.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-683.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1473.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-716.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-752.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1766.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-31.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-819.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-63.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-851.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-99.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-883.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-131.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-915.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-163.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-947.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-195.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-979.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-227.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1011.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-259.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-291.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-323.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-355.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1148.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-389.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1180.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-423.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-459.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1244.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-491.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1276.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1510.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-523.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1308.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1542.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-555.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1343.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1577.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-590.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1375.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-622.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1407.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-654.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1444.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1673.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-686.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1477.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1705.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-723.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1737.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-755.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-789.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-34.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-822.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-66.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-854.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-102.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-134.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-918.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-166.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-950.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-198.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-982.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-230.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1014.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-262.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1046.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-294.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1078.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-326.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1110.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-358.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1151.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-392.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1183.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-426.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1215.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-462.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1247.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-494.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1279.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1513.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-526.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1311.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1545.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-558.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1346.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1580.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-593.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1378.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-625.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1410.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1644.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-657.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1447.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1676.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-689.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1480.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1708.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-726.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1740.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-758.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-793.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-37.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-825.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-69.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-857.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-105.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-889.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-137.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-921.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-169.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-953.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-201.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-233.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1017.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-265.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1049.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-297.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-329.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1113.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-361.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1154.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-395.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1186.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-429.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1218.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-465.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1250.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1483.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-497.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1282.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1516.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-529.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1314.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1548.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-561.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1349.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1583.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-596.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1381.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1615.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-628.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1413.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1647.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-660.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1450.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-692.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1711.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-729.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1743.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-761.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-4.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-796.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-40.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-828.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-75.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-860.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-108.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-892.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-140.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-924.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-172.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-956.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-204.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-236.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1020.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-268.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1052.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-300.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1084.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-332.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1116.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-366.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1157.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-398.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1189.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-432.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1221.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-468.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1253.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1486.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-500.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1285.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1519.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-532.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1317.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-564.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1352.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1586.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-599.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1384.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1618.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-631.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1416.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1650.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-663.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1453.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-695.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1714.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-732.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1746.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-764.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-7.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-799.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-43.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-831.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-78.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-863.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-111.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-895.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-143.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-927.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-175.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-959.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-207.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-991.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-239.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1023.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-271.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1055.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-303.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1087.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-335.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1123.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-369.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1160.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-401.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1192.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-435.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1224.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-471.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1256.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1489.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-503.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1522.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-535.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1320.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1554.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-567.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1355.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1589.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-602.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1387.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1621.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-634.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1419.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1653.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-666.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1456.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-698.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1717.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-735.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1749.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-767.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-10.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-802.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-46.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-834.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-81.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-866.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-114.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-898.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-146.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-930.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-178.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-962.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-210.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-994.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-242.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1026.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-274.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1058.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-306.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-338.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1126.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-372.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1163.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-404.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1195.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-438.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1227.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-474.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1259.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1492.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-506.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1291.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1525.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-538.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1323.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1557.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-570.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1358.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1592.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-605.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1390.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1624.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-637.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1427.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1656.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-669.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1459.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1688.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-701.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1720.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-738.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1752.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-770.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-17.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-805.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-49.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-837.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-84.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-869.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-117.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-149.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-933.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-181.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-965.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-213.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-997.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-245.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1029.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-277.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1061.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-309.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-341.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1129.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-375.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1166.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-407.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1198.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-445.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1230.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-477.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1262.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1495.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-509.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1294.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1528.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-541.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1326.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1560.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-573.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-576.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1361.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1595.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-608.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1393.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1627.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-640.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1430.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1659.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-672.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1462.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1691.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-704.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1723.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-741.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1755.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-775.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-20.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-808.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-52.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-840.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-87.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-872.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-120.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-904.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-152.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-936.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-184.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-968.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-216.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1000.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-248.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1032.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-280.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1064.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-312.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1096.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-344.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1132.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-378.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1169.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-410.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1201.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-448.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1233.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-480.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1498.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-512.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1297.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1531.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-544.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1329.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1563.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1566.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-579.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1364.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1598.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-611.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1396.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1630.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-643.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1433.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1662.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-675.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1465.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-707.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1726.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-744.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1758.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-778.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-23.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-811.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-55.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-843.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-90.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-875.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-123.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-907.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-155.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-939.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-187.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-971.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-219.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1003.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-251.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1035.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-283.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1067.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-315.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1099.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-347.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1135.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-381.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1172.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-413.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1204.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-451.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1236.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-483.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1268.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1502.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-515.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1300.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1534.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-547.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1332.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1569.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-582.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1367.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1601.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-614.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1399.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1633.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-646.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1436.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1665.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-678.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1468.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1697.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-710.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1729.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-747.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1761.png
# ...
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-183.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-215.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-999.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-247.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1031.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-279.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1063.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-311.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1095.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-343.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1131.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-377.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1168.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-409.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1200.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-447.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1232.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-479.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1264.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1497.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-511.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1296.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1530.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-543.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1328.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1562.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-575.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-578.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1363.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-610.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-642.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1432.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1661.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-674.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1464.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-706.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1725.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-743.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1757.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-777.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-22.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-810.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-54.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-842.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-89.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-874.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-122.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-906.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-154.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-938.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-186.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-970.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-218.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1002.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-250.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1034.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-282.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1066.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-314.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1098.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-346.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1134.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-380.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1171.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-412.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-450.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1235.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-482.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1267.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1501.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-514.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1299.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1533.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-546.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1331.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1565.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-569.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1357.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1591.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-604.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1389.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1623.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-636.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1424.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1655.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-668.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1458.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-700.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-737.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-769.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-12.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-804.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-48.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-836.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-83.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-868.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-116.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-900.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-148.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-932.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-180.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-212.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-996.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-244.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1028.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-276.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1060.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-308.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1092.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-340.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1128.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-374.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1165.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-406.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1197.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-440.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1229.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-476.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1261.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1494.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-508.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1293.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1527.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-540.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1325.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1559.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-572.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1406.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1640.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-653.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1443.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1672.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-685.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1475.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-722.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1736.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-754.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1768.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-788.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-33.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-821.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-65.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-853.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-613.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1398.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1632.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-645.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1435.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1664.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-677.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1467.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1696.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-709.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1728.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-746.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1760.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-780.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-25.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-813.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-57.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-845.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-93.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-877.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-125.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-909.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-157.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-941.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-189.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-973.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-221.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1005.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-253.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1037.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-285.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1069.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-317.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1101.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-349.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1137.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-383.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-938.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-186.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-970.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-218.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1002.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-250.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1034.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-282.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1066.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-314.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-1098.png
# /home/ext/dumitriu/datasets/rip_current_akila/training_data/with_rips/rip-346.png
# Finished parsing data from file.
# Converting annotations to yolo format and writing files.
# Finished writing yolo annotations to files.
